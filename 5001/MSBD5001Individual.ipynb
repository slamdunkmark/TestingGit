# %% [markdown]
# ## Individual Project

# %% [markdown]
# ## 导入必要标准库

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# First Deals with Missing Data
dataset = pd.read_csv('train.csv')
testing_data=pd.read_csv('test.csv')
dataset=dataset[dataset["purchase_date"].notnull()]
testing_data=testing_data[testing_data["purchase_date"].notnull()]
def kesson_table(df):
        null_val = df.isnull().sum()
        percent = 100 * df.isnull().sum()/len(df)
        kesson_table = pd.concat([null_val, percent], axis =1)
        kesson_table_ren_columns = kesson_table.rename(
        columns = {0 : 'Missing Data', 1 :'%'})
        return kesson_table_ren_columns

# %% [markdown]
# ## Check Missing Data

# %%
kesson_table(dataset)
# Out:
#                         Missing Data    %
# id                                 0  0.0
# playtime_forever                   0  0.0
# is_free                            0  0.0
# price                              0  0.0
# genres                             0  0.0
# categories                         0  0.0
# tags                               0  0.0
# purchase_date                      0  0.0
# release_date                       0  0.0
# total_positive_reviews             0  0.0
# total_negative_reviews             0  0.0

# %%
dataset
# Out:
#       id  playtime_forever  is_free    price                  genres  \
# 0      0          0.000000    False   3700.0  Adventure,Casual,Indie
# 1      1          0.016667     True      0.0                     RPG
# 2      2          0.000000    False   5000.0  Adventure,Casual,Indie
# 3      3          1.533333    False   9900.0              Action,RPG
# 4      4         22.333333    False   4800.0   Action,Indie,Strategy
# ..   ...               ...      ...      ...                     ...
# 352  352          0.783333    False   8800.0       Action,Simulation
# 353  353          0.000000    False   6800.0        Action,Adventure
# 354  354          0.000000    False   8300.0    Action,Adventure,RPG
# 355  355          0.000000    False   6800.0        Action,Adventure
# 356  356          0.000000    False  10000.0          Indie,Strategy
#
#                                             categories  \
# 0        Single-player,Steam Trading Cards,Steam Cloud
# ...

# %%
kesson_table(testing_data)
# Out:
#                         Missing Data    %
# id                                 0  0.0
# is_free                            0  0.0
# price                              0  0.0
# genres                             0  0.0
# categories                         0  0.0
# tags                               0  0.0
# purchase_date                      0  0.0
# release_date                       0  0.0
# total_positive_reviews             0  0.0
# total_negative_reviews             0  0.0

# %%
testing_data
# Out:
#     id  is_free  price                                           genres  \
# 0    0    False   3500                                 Action,Adventure
# 1    1    False  11600                        Action,Adventure,Strategy
# 2    2    False   2100                        Indie,Simulation,Strategy
# 3    3    False   3600                                  Action,Strategy
# 4    4    False   3400                                 Action,Adventure
# ..  ..      ...    ...                                              ...
# 85  85    False   5000                                           Action
# 86  86    False   3600                                 Action,Adventure
# 87  87    False  11200                              Simulation,Strategy
# 88  88     True      0  Action,Adventure,RPG,Simulation,Sports,Strategy
# 89  89    False  26800                                  Action,Strategy
#
#                                            categories  \
# ...

# %% [markdown]
# ## Deals with is_free

# %%
def deal_with_is_free(x):
    if x == False:
        return 0
    else:
        return 1
dataset["is_free"]=dataset["is_free"].apply(deal_with_is_free)
testing_data["is_free"]=testing_data["is_free"].apply(deal_with_is_free)

# %% [markdown]
# ## Deals with price

# %%
# We will use Feature Scaling in the end

# %% [markdown]
# ## Deals with genres(Training Set)

# %%
dataset["genres"]=dataset["genres"].str.split(',')
np.concatenate(dataset["genres"].values)
new=pd.DataFrame({'genres':np.concatenate(dataset["genres"].values),'id':dataset.id.repeat(dataset.genres.apply(len))})
a=new.groupby('genres').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["genres"])
new2=new1.groupby("id").percentage.agg(["sum"])
dataset["genres_prob"]=new2["sum"]

# %% [markdown]
# ## Deals with genres(Test Set)

# %%
testing_data["genres"]=testing_data["genres"].str.split(',')
np.concatenate(testing_data["genres"].values)
new=pd.DataFrame({'genres':np.concatenate(testing_data["genres"].values),'id':testing_data.id.repeat(testing_data.genres.apply(len))})
a=new.groupby('genres').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["genres"])
new2=new1.groupby("id").percentage.agg(["sum"])
testing_data["genres_prob"]=new2["sum"]
# Out:
#     id  is_free  price                                             genres  \
# 0    0        0   3500                                [Action, Adventure]
# 1    1        0  11600                      [Action, Adventure, Strategy]
# 2    2        0   2100                      [Indie, Simulation, Strategy]
# 3    3        0   3600                                 [Action, Strategy]
# 4    4        0   3400                                [Action, Adventure]
# ..  ..      ...    ...                                                ...
# 85  85        0   5000                                           [Action]
# 86  86        0   3600                                [Action, Adventure]
# 87  87        0  11200                             [Simulation, Strategy]
# 88  88        1      0  [Action, Adventure, RPG, Simulation, Sports, S...
# 89  89        0  26800                                 [Action, Strategy]
#
#                                            categories  \
# ...

# %% [markdown]
# ## Dealing with categories(Training)

# %%
dataset["categories"]=dataset["categories"].str.split(',')
np.concatenate(dataset["categories"].values)
new=pd.DataFrame({'categories':np.concatenate(dataset["categories"].values),'id':dataset.id.repeat(dataset.categories.apply(len))})
a=new.groupby('categories').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["categories"])
new2=new1.groupby("id").percentage.agg(["sum"])
dataset["categories_prob"]=new2["sum"]

# %% [markdown]
# ## Dealing with categories(Testing)

# %%
testing_data["categories"]=testing_data["categories"].str.split(',')
np.concatenate(testing_data["categories"].values)
new=pd.DataFrame({'categories':np.concatenate(testing_data["categories"].values),'id':testing_data.id.repeat(testing_data.categories.apply(len))})
a=new.groupby('categories').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["categories"])
new2=new1.groupby("id").percentage.agg(["sum"])
testing_data["categories_prob"]=new2["sum"]

# %% [markdown]
# ## Dealing with tags(Training)

# %%
dataset["tags"]=dataset["tags"].str.split(',')
np.concatenate(dataset["tags"].values)
new=pd.DataFrame({'tags':np.concatenate(dataset["tags"].values),'id':dataset.id.repeat(dataset.tags.apply(len))})
a=new.groupby('tags').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["tags"])
new2=new1.groupby("id").percentage.agg(["sum"])
dataset["tags_prob"]=new2["sum"]

# %% [markdown]
# ## Dealing with tags(Testing)

# %%
testing_data["tags"]=testing_data["tags"].str.split(',')
np.concatenate(testing_data["tags"].values)
new=pd.DataFrame({'tags':np.concatenate(testing_data["tags"].values),'id':testing_data.id.repeat(testing_data.tags.apply(len))})
a=new.groupby('tags').id.agg(['count'])
a["percentage"]=a["count"]/a["count"].sum()
new1=pd.merge(a, new, how='right', on=["tags"])
new2=new1.groupby("id").percentage.agg(["sum"])
testing_data["tagss_prob"]=new2["sum"]

# %%
testing_data
# Out:
#     id  is_free  price                                             genres  \
# 0    0        0   3500                                [Action, Adventure]
# 1    1        0  11600                      [Action, Adventure, Strategy]
# 2    2        0   2100                      [Indie, Simulation, Strategy]
# 3    3        0   3600                                 [Action, Strategy]
# 4    4        0   3400                                [Action, Adventure]
# ..  ..      ...    ...                                                ...
# 85  85        0   5000                                           [Action]
# 86  86        0   3600                                [Action, Adventure]
# 87  87        0  11200                             [Simulation, Strategy]
# 88  88        1      0  [Action, Adventure, RPG, Simulation, Sports, S...
# 89  89        0  26800                                 [Action, Strategy]
#
#                                            categories  \
# ...

# %%
Good_or_Bad=dataset.loc[:,["id","total_positive_reviews","total_negative_reviews","playtime_forever"]]
Good_or_Bad["Rate_Total"]=dataset["total_positive_reviews"]+dataset["total_negative_reviews"]
Good_or_Bad["Good_Rate"]=dataset["total_positive_reviews"]/Good_or_Bad["Rate_Total"]*100
Good_or_Bad["Bad_Rate"]=dataset["total_negative_reviews"]/Good_or_Bad["Rate_Total"]*100
Good_or_Bad.loc[Good_or_Bad["Rate_Total"]==0,"Good_Rate"]=0
Good_or_Bad.loc[Good_or_Bad["Rate_Total"]==0,"Bad_Rate"]=0
Good_or_Bad
# Out:
#       id  total_positive_reviews  total_negative_reviews  playtime_forever  \
# 0      0                   372.0                    96.0          0.000000
# 1      1                    23.0                     0.0          0.016667
# 2      2                  3018.0                   663.0          0.000000
# 3      3                 63078.0                  1746.0          1.533333
# 4      4                  8841.0                   523.0         22.333333
# ..   ...                     ...                     ...               ...
# 352  352                   150.0                    91.0          0.783333
# 353  353                 19008.0                  4849.0          0.000000
# 354  354                  5099.0                  1719.0          0.000000
# 355  355                   718.0                   159.0          0.000000
# 356  356                   915.0                   102.0          0.000000
#
#      Rate_Total   Good_Rate   Bad_Rate
# ...

# %%
# Out:
#     id  is_free  price                                           genres  \
# 0    0    False   3500                                 Action,Adventure
# 1    1    False  11600                        Action,Adventure,Strategy
# 2    2    False   2100                        Indie,Simulation,Strategy
# 3    3    False   3600                                  Action,Strategy
# 4    4    False   3400                                 Action,Adventure
# ..  ..      ...    ...                                              ...
# 85  85    False   5000                                           Action
# 86  86    False   3600                                 Action,Adventure
# 87  87    False  11200                              Simulation,Strategy
# 88  88     True      0  Action,Adventure,RPG,Simulation,Sports,Strategy
# 89  89    False  26800                                  Action,Strategy
#
#                                            categories  \
# ...

# %% [markdown]
# ## We found out that the playtime is correlated to total_positive reviews

# %%
dataset.corr().style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col0 {
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col1 {
#             background-color:  #4c66d6;
#             color:  #000000;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col2 {
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col3 {
#             background-color:  #4f69d9;
#             color:  #000000;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col4 {
#             background-color:  #5b7ae5;
#             color:  #000000;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row0_col5 {
#             background-color:  #5470de;
#             color:  #000000;
#         }    #T_ac3ea27a_f606_11e9_9d5c_e454e8170736row1_col0 {
#             background-color:  #5f7fe8;
#             color:  #000000;
# ...

# %% [markdown]
# ## Dealing with is_Free

# %%
dataset
# Out:
#       id  playtime_forever  is_free    price                  genres  \
# 0      0          0.000000    False   3700.0  Adventure,Casual,Indie
# 1      1          0.016667     True      0.0                     RPG
# 2      2          0.000000    False   5000.0  Adventure,Casual,Indie
# 3      3          1.533333    False   9900.0              Action,RPG
# 4      4         22.333333    False   4800.0   Action,Indie,Strategy
# ..   ...               ...      ...      ...                     ...
# 352  352          0.783333    False   8800.0       Action,Simulation
# 353  353          0.000000    False   6800.0        Action,Adventure
# 354  354          0.000000    False   8300.0    Action,Adventure,RPG
# 355  355          0.000000    False   6800.0        Action,Adventure
# 356  356          0.000000    False  10000.0          Indie,Strategy
#
#                                             categories  \
# 0        Single-player,Steam Trading Cards,Steam Cloud
# ...

# %% [markdown]
# ## Dealing with Model

# %%
dataset["Rate_Total"]=dataset["total_positive_reviews"]+dataset["total_negative_reviews"]
dataset["Good_Rate"]=dataset["total_positive_reviews"]/Good_or_Bad["Rate_Total"]*100
dataset["Bad_Rate"]=dataset["total_negative_reviews"]/Good_or_Bad["Rate_Total"]*100
dataset.loc[dataset["Rate_Total"]==0,"Good_Rate"]=0
dataset.loc[dataset["Rate_Total"]==0,"Bad_Rate"]=0
X = dataset.loc[:, ["price","Good_Rate","Rate_Total"]].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)

# %%
y_pred = regressor.predict(X_test)

# %% [markdown]
# ## Start Trying the model

# %%
def mymodel(dataset):
    dataset=dataset[dataset["purchase_date"].notnull()]
    dataset["Rate_Total"]=dataset["total_positive_reviews"]+dataset["total_negative_reviews"]
    dataset["Good_Rate"]=dataset["total_positive_reviews"]/dataset["Rate_Total"]*100
    dataset["Bad_Rate"]=dataset["total_negative_reviews"]/dataset["Rate_Total"]*100
    dataset.loc[dataset["Rate_Total"]==0,"Good_Rate"]=0
    dataset.loc[dataset["Rate_Total"]==0,"Bad_Rate"]=0
    X_Test = dataset.loc[:, ["price","Good_Rate","Rate_Total"]].values
    return X_Test

# %% [markdown]
# ## Model Check on itself

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse = sqrt(mean_squared_error(y_test, y_pred))
print(rmse)
# Out:
# 5.724857373629108

# %% [markdown]
# ## Model Check on Test

# %%
X_Test=mymodel(testset)
# Out:
# C:\Users\qnche\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# C:\Users\qnche\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
# C:\Users\qnche\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: SettingWithCopyWarning:
# ...

# %%
testset.describe()
testset.info()
# Out:
#   File "<ipython-input-119-115293c35f3e>", line 3
#     ipynb-py-convert examples/plot.ipynb examples/plot.py
#                             ^
# SyntaxError: invalid syntax

# %%
X_Test
# Out:
# array([[3.50000000e+03, 5.57051282e+02, 3.72900000e+03],
#        [1.16000000e+04, 2.50521739e+04, 7.99700000e+03],
#        [2.10000000e+03, 1.86634067e+01, 8.20000000e+02],
#        [3.60000000e+03, 1.03356781e-01, 1.06000000e+02],
#        [3.40000000e+03, 4.30841521e+02, 4.40520000e+04],
#        [6.80000000e+03,            nan, 4.68000000e+02],
#        [6.80000000e+03, 3.98912058e+00, 1.98800000e+03],
#        [1.80000000e+03, 7.11111111e+02, 3.39000000e+02],
#        [6.80000000e+03, 9.26332288e+01, 3.06300000e+03],
#        [2.99900000e+03, 6.67586207e+03, 4.87800000e+03],
#        [1.16000000e+04, 1.97937206e+01, 1.55100000e+03],
#        [6.40000000e+03, 3.53278689e+03, 7.27100000e+03],
#        [4.20000000e+03, 8.72259028e+01, 1.00870000e+04],
#        [6.80000000e+03, 3.30878231e+02, 2.61010000e+04],
#        [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#        [4.30000000e+03, 5.34675126e+00, 1.30400000e+03],
# ...

# %%
y_pred = regressor.predict(X_Test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-88-9b4b22d537de> in <module>
# ----> 1 y_pred = regressor.predict(X_Test)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in predict(self, X)
#     219             Returns predicted values.
#     220         """
# --> 221         return self._decision_function(X)
#     222
#     223     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\Anaconda3\lib\site-packages\sklearn\linear_model\base.py in _decision_function(self, X)
#     202         check_is_fitted(self, "coef_")
#     203
# --> 204         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
#     205         return safe_sparse_dot(X, self.coef_.T,
#     206                                dense_output=True) + self.intercept_
#
# ...

# %%
result=pd.
result.to_csv("result.csv")
